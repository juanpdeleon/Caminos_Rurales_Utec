# %%
import cv2
import copy
from ultralytics import solutions
import os
import shutil
import json
from libreria import preocess_input_video

# Leer el archivo de configuración de los parametros 
with open("config.json", "r") as file:
    config = json.load(file)

# Acceder a los parámetros
Input_files = config["Input_files"]  # Ubicacion a donde van a estar los archivos originales
Output_files = config["Output_files"] # ubicacion a donde se guaardan las imagnes y los json
Backup_files = config["Backup_files"] # Ubicacion a donde se hace el respaldo de los archivos
Log_dir = config["Log_dir"]   #implementar las salidas del print a un archivo de log, para ver los errores ya que el procedimiento gira automatico.
preocess_input_video

#LLamada al sistema 
# Terimnar de implementar, para los parametros recibidos por el JSON 
preocess_input_video(Input_files,Output_files,Backup_files,Log_dir) #Directorios que la aplicacion "Entrada, Sadlida, Respaldo y log de mensajes para analisis"
# Out:
# video_toten1_14-11-2024_01_11.mp4
# Ultralytics Solutions:  {'region': [(10, 350), (1300, 350)], 'show_in': True, 'show_out': True, 'colormap': None, 'up_angle': 145.0, 'down_angle': 90, 'kpts': [6, 8, 10], 'analytics_type': 'line', 'json_file': None, 'show': True, 'model': 'yolo11n.pt', 'classes': [1, 2, 3, 5, 7], 'verbose': False}
#
# 0: 480x640 4 cars, 1 bus, 1 truck, 14.2ms
# Speed: 2.9ms preprocess, 14.2ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#  Vehiculos agregados : {('car', (('IN', 0), ('OUT', 0))), ('bus', (('IN', 0), ('OUT', 0))), ('truck', (('IN', 0), ('OUT', 0)))}
# Object 3 crossed the box! Bounding Box: tensor([250.0864, 320.0242, 328.6608, 464.3811])
# SALLIDA DE TEMP : ['car', 0, 0]
# {3}
# ['X', 'video_toten1_14-11-2024_01_11.mp4_track_3_frame_1.jpg', 'car', 0, 'XXX0000', '0']
# Archivo JSON creado exitosamente.
# ./salidas/jsonfile/video_toten1_14-11-2024_01_11.mp4_track_3_frame_1
# ...
