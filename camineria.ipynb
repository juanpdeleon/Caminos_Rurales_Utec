# %%
import numpy as np

import cv2
from ultralytics import YOLO
from sort import Sort

# %%
def convertir(input_file, output_file, width=1024, height=768):
    # Captura el video de entrada
    cap = cv2.VideoCapture(input_file)

    # Verifica si se abrió el video correctamente
    if not cap.isOpened():
        print(f"No se pudo abrir el archivo: {input_file}")
        return

    # Obtener la resolución original
    original_width = int(cap.get(cv2.CAP_PROP_FRAME_WIDTH))
    original_height = int(cap.get(cv2.CAP_PROP_FRAME_HEIGHT))

    print(f"Resolución original: {original_width}x{original_height}")

    # Si la resolución es mayor que 1024x768, redimensionar
    if original_width > width or original_height > height:
        print("Redimensionando video...")
        # Obtener la tasa de cuadros y el codec del video original
        fps = cap.get(cv2.CAP_PROP_FPS)
        fourcc = cv2.VideoWriter_fourcc(*'mp4v')  # Codec para archivos MP4

        # Crear el objeto VideoWriter para el video de salida
        out = cv2.VideoWriter(output_file, fourcc, fps, (width, height))

        while True:
            ret, frame = cap.read()
            if not ret:
                break

            # Cambiar la resolución del frame
            resized_frame = cv2.resize(frame, (width, height))

            # Escribir el frame redimensionado en el video de salida
            out.write(resized_frame)

        # Liberar los objetos
        out.release()
        print(f"Video redimensionado guardado como: {output_file}")
    else:
        print("La resolución es adecuada. No se necesita redimensionar.")

    # Liberar el objeto de captura
    cap.release()

# %%
input_file = 'videos/Ejemplo1.mp4'  # Cambia esto por tu archivo de entrada
output_file = 'videos/video.mp4'  # Archivo de salida
   
convertir(input_file, output_file)
# Out:
# Resolución original: 1280x720
# Redimensionando video...
# Video redimensionado guardado como: videos/video.mp4

# %%
if __name__ == '__main__':
    cap = cv2.VideoCapture("videos/video.mp4")
    Y_minimo=450
    Y_maximo=500
    linea1 = [(0,Y_minimo),(1023,Y_minimo)]
    linea2 = [(0,Y_maximo),(1023,Y_maximo)]
    
              
    
    # Diccionario para contar las detecciones por clase
    clases_yolo = ["persona", "bicleta", "Auto", "Moto", "Avion", "Omnibus", "Tren", "Camion"]        
    deteccion_por_clase = {class_name: 0 for class_name in clases_yolo}
    objetos_contados = set()

    model = YOLO("yolov8s.pt")

    tracker = Sort()
    

    while cap.isOpened():
        status, frame = cap.read()

        if not status:
            break

        results = model(frame, stream=True)
        objetos_en_frame = set()  # Conjunto de IDs de objetos en el frame actual

        for res in results:
            filtered_indices = np.where((np.isin(res.boxes.cls.cpu().numpy(),[2,3,5,7])) & (res.boxes.conf.cpu().numpy()>0.4))[0] # Filtrar clases 2,3,5,7 => autos,motos,omnibus,camiones con mas de 40%
            boxes = res.boxes.xyxy.cpu().numpy()[filtered_indices].astype(int)
            class_indices = res.boxes.cls.cpu().numpy()[filtered_indices].astype(int)
            
            tracks = tracker.update(boxes)
            tracks = tracks.astype(int)
            
            cv2.line(frame,linea1[0],linea1[1],(255,0,0),3)
            cv2.line(frame,linea2[0],linea2[1],(255,0,0),3)
            
            
            #for xmin, ymin, xmax, ymax, track_id in tracks:
            for i, (xmin, ymin, xmax, ymax, track_id) in enumerate(tracks):
                # Obtener el índice de clase correspondiente y su nombre
                class_index = class_indices[i]
                class_name = clases_yolo[class_index]           
                xc,yc = int((xmin+xmax)/2),ymax
                
                print("Poscicion:")
                print(xc,yc,ymax)
                
                if (yc>Y_minimo and yc<Y_maximo):
                    if track_id not in objetos_contados:
                        # Incrementar el conteo de la clase detectada
                        deteccion_por_clase[class_name] += 1
                        # Agregar el ID al conjunto de objetos contados
                        objetos_contados.add(track_id)

                cv2.circle(img=frame, center=[xc,yc], radius=4, color=[0,255,0] , thickness=-1)
                cv2.rectangle(img=frame, pt1=(xmin, ymin), pt2=(xmax, ymax), color=(0, 255, 0), thickness=2)
                cv2.putText(img=frame, text=f"Id: {track_id}", org=(xmin, ymin-25), fontFace=cv2.FONT_HERSHEY_PLAIN, fontScale=1, color=(0, 255, 0), thickness=2)
                # Imprimir el nombre de la clase sobre el cuadro
                cv2.putText(img=frame, text=f"Clase: {class_name}", org=(xmin, ymin-10), fontFace=cv2.FONT_HERSHEY_PLAIN, fontScale=1, color=(0, 255, 0), thickness=2)
                cv2.putText(img=frame, text=f"Y : {yc}", org=(xmax, ymax-10), fontFace=cv2.FONT_HERSHEY_PLAIN, fontScale=1, color=(0, 255, 0), thickness=2)

      
        y_offset = 30  # Espaciado entre cada texto
        start_y = 50   # Ajusta esta coordenada para subir/bajar el texto en la pantalla
        for idx, (class_name, count) in enumerate(deteccion_por_clase.items()):
            if count > 0:  # Mostrar solo las clases que tienen detecciones
                text = f"{class_name}: {count}"
                # Colocar el texto en la parte superior izquierda de la pantalla
                cv2.putText(frame, text, (10, start_y + idx * y_offset), cv2.FONT_HERSHEY_SIMPLEX, 0.8, (0, 255, 0), 2)
        
        # frame = results[0].plot()

        cv2.imshow("frame", frame)

        if cv2.waitKey(1) & 0xFF == ord("q"):
            break
    
    cap.release()
    cv2.destroyAllWindows()
# Out:
# 0: 480x640 6 cars, 2 trucks, 173.2ms
# Poscicion:
# 11 330 330
# Poscicion:
# 684 343 343
# Poscicion:
# 589 336 336
# Poscicion:
# 486 347 347
# Poscicion:
# 664 460 460
# Poscicion:
# 432 455 455
# Poscicion:
# 329 477 477
# Speed: 2.0ms preprocess, 173.2ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 7 cars, 2 trucks, 148.8ms
# Poscicion:
# 431 363 363
# Poscicion:
# 12 329 329
# Poscicion:
# 589 336 336
# Poscicion:
# 485 346 346
# Poscicion:
# 661 457 457
# Poscicion:
# 429 458 458
# Poscicion:
# 324 481 481
# Speed: 3.0ms preprocess, 148.8ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 8 cars, 2 trucks, 146.0ms
# Poscicion:
# 429 362 362
# Poscicion:
# 12 330 330
# Poscicion:
# 588 335 335
# Poscicion:
# 484 348 348
# Poscicion:
# 657 453 453
# Poscicion:
# 426 461 461
# Poscicion:
# 320 485 485
# Speed: 2.0ms preprocess, 146.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 8 cars, 1 truck, 149.0ms
# Poscicion:
# 12 330 330
# Poscicion:
# 587 335 335
# Poscicion:
# 484 349 349
# Poscicion:
# 655 449 449
# Poscicion:
# 424 467 467
# Poscicion:
# 316 490 490
# Speed: 2.0ms preprocess, 149.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 8 cars, 2 trucks, 144.0ms
# Poscicion:
# 12 330 330
# Poscicion:
# 587 334 334
# Poscicion:
# 483 351 351
# Poscicion:
# 653 446 446
# Poscicion:
# 422 471 471
# Poscicion:
# 311 497 497
# Speed: 2.0ms preprocess, 144.0ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 8 cars, 2 trucks, 150.1ms
# Poscicion:
# 12 330 330
# Poscicion:
# 586 333 333
# Poscicion:
# 483 353 353
# Poscicion:
# 652 444 444
# Poscicion:
# 421 476 476
# Poscicion:
# 306 503 503
# Speed: 2.0ms preprocess, 150.1ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 8 cars, 1 truck, 150.0ms
# Poscicion:
# 12 330 330
# Poscicion:
# 586 333 333
# Poscicion:
# 481 354 354
# Poscicion:
# 651 441 441
# Poscicion:
# 420 481 481
# Poscicion:
# 302 510 510
# Speed: 2.0ms preprocess, 150.0ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 8 cars, 1 truck, 148.6ms
# Poscicion:
# 425 369 369
# Poscicion:
# 12 330 330
# Poscicion:
# 586 332 332
# Poscicion:
# 480 355 355
# Poscicion:
# 649 439 439
# Poscicion:
# 417 486 486
# Poscicion:
# 296 515 515
# Speed: 2.0ms preprocess, 148.6ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 8 cars, 2 trucks, 150.0ms
# Poscicion:
# 458 346 346
# Poscicion:
# 550 322 322
# Poscicion:
# 423 371 371
# Poscicion:
# 12 330 330
# Poscicion:
# 586 332 332
# Poscicion:
# 479 356 356
# Poscicion:
# 647 437 437
# Poscicion:
# 415 491 491
# Poscicion:
# 291 524 524
# Speed: 2.0ms preprocess, 150.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 9 cars, 2 trucks, 142.2ms
# Poscicion:
# 457 348 348
# Poscicion:
# 551 321 321
# Poscicion:
# 423 372 372
# Poscicion:
# 12 330 330
# Poscicion:
# 586 331 331
# Poscicion:
# 645 434 434
# Poscicion:
# 413 497 497
# Poscicion:
# 285 532 532
# Speed: 2.0ms preprocess, 142.2ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 9 cars, 2 trucks, 141.5ms
# Poscicion:
# 458 350 350
# Poscicion:
# 421 374 374
# Poscicion:
# 12 330 330
# Poscicion:
# 586 330 330
# Poscicion:
# 643 431 431
# Poscicion:
# 410 504 504
# Poscicion:
# 279 539 539
# Speed: 2.0ms preprocess, 141.5ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 8 cars, 2 trucks, 143.0ms
# Poscicion:
# 457 351 351
# Poscicion:
# 421 376 376
# Poscicion:
# 12 330 330
# Poscicion:
# 585 330 330
# Poscicion:
# 643 429 429
# Poscicion:
# 408 510 510
# Speed: 2.0ms preprocess, 143.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 8 cars, 3 trucks, 140.0ms
# Poscicion:
# 457 352 352
# Poscicion:
# 419 377 377
# Poscicion:
# 11 330 330
# Poscicion:
# 585 330 330
# Poscicion:
# 641 427 427
# Poscicion:
# 405 515 515
# Speed: 2.0ms preprocess, 140.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 9 cars, 2 trucks, 143.0ms
# Poscicion:
# 456 353 353
# Poscicion:
# 417 377 377
# Poscicion:
# 11 330 330
# Poscicion:
# 585 330 330
# Poscicion:
# 640 424 424
# Poscicion:
# 403 523 523
# Speed: 2.0ms preprocess, 143.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 7 cars, 2 trucks, 1 suitcase, 154.0ms
# Poscicion:
# 420 379 379
# Poscicion:
# 456 355 355
# Poscicion:
# 11 330 330
# Poscicion:
# 586 329 329
# Poscicion:
# 639 422 422
# Poscicion:
# 399 530 530
# Speed: 3.0ms preprocess, 154.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 7 cars, 1 truck, 166.2ms
# Poscicion:
# 422 381 381
# Poscicion:
# 455 355 355
# Poscicion:
# 11 330 330
# Poscicion:
# 637 420 420
# Poscicion:
# 396 536 536
# Speed: 2.0ms preprocess, 166.2ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 7 cars, 2 trucks, 141.0ms
# Poscicion:
# 422 383 383
# Poscicion:
# 455 356 356
# Poscicion:
# 11 330 330
# Poscicion:
# 636 418 418
# Poscicion:
# 392 545 545
# Speed: 10.0ms preprocess, 141.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 7 cars, 4 trucks, 152.0ms
# Poscicion:
# 421 384 384
# Poscicion:
# 454 357 357
# Poscicion:
# 11 330 330
# Poscicion:
# 635 416 416
# Poscicion:
# 389 554 554
# Poscicion:
# 224 611 611
# Speed: 2.0ms preprocess, 152.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 7 cars, 4 trucks, 157.0ms
# Poscicion:
# 421 386 386
# Poscicion:
# 452 358 358
# Poscicion:
# 11 330 330
# Poscicion:
# 583 327 327
# Poscicion:
# 634 415 415
# Poscicion:
# 385 562 562
# Poscicion:
# 214 624 624
# Speed: 2.0ms preprocess, 157.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 9 cars, 3 trucks, 153.0ms
# Poscicion:
# 413 391 391
# Poscicion:
# 452 359 359
# Poscicion:
# 11 330 330
# Poscicion:
# 582 326 326
# Poscicion:
# 631 412 412
# Poscicion:
# 381 572 572
# Poscicion:
# 204 637 637
# Speed: 2.0ms preprocess, 153.0ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 8 cars, 3 trucks, 145.0ms
# Poscicion:
# 452 360 360
# Poscicion:
# 582 326 326
# Poscicion:
# 630 409 409
# Poscicion:
# 377 583 583
# Poscicion:
# 193 652 652
# Speed: 3.0ms preprocess, 145.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 6 cars, 4 trucks, 165.0ms
# Poscicion:
# 582 325 325
# Poscicion:
# 629 407 407
# Poscicion:
# 372 594 594
# Poscicion:
# 180 667 667
# Speed: 2.0ms preprocess, 165.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 8 cars, 2 trucks, 143.0ms
# Poscicion:
# 582 325 325
# Poscicion:
# 629 405 405
# Poscicion:
# 368 605 605
# Poscicion:
# 167 684 684
# Speed: 2.0ms preprocess, 143.0ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 6 cars, 3 trucks, 146.2ms
# Poscicion:
# 629 404 404
# Poscicion:
# 363 618 618
# Poscicion:
# 152 704 704
# Speed: 2.0ms preprocess, 146.2ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 5 cars, 1 truck, 166.5ms
# Poscicion:
# 628 403 403
# Poscicion:
# 357 631 631
# Poscicion:
# 137 726 726
# Speed: 2.0ms preprocess, 166.5ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 5 cars, 1 bus, 1 truck, 143.0ms
# Poscicion:
# 627 401 401
# Poscicion:
# 351 646 646
# Poscicion:
# 119 752 752
# Speed: 2.0ms preprocess, 143.0ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 8 cars, 2 trucks, 146.0ms
# Poscicion:
# 625 399 399
# Poscicion:
# 345 662 662
# Poscicion:
# 101 765 765
# Speed: 5.0ms preprocess, 146.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 7 cars, 2 trucks, 144.0ms
# Poscicion:
# 623 397 397
# Poscicion:
# 338 679 679
# Speed: 3.0ms preprocess, 144.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 6 cars, 2 trucks, 148.5ms
# Poscicion:
# 622 395 395
# Poscicion:
# 331 698 698
# Speed: 2.0ms preprocess, 148.5ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 7 cars, 1 truck, 147.0ms
# Poscicion:
# 621 393 393
# Poscicion:
# 323 718 718
# Speed: 3.0ms preprocess, 147.0ms inference, 0.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 6 cars, 2 trucks, 144.5ms
# Poscicion:
# 11 329 329
# Poscicion:
# 620 392 392
# Poscicion:
# 314 742 742
# Speed: 2.0ms preprocess, 144.5ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 5 cars, 1 truck, 145.5ms
# Poscicion:
# 11 329 329
# Poscicion:
# 619 391 391
# Poscicion:
# 305 761 761
# Speed: 2.0ms preprocess, 145.5ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 cars, 1 truck, 145.0ms
# Poscicion:
# 384 417 417
# Poscicion:
# 11 329 329
# Poscicion:
# 618 390 390
# Poscicion:
# 294 772 772
# Speed: 2.0ms preprocess, 145.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 cars, 1 truck, 166.0ms
# Poscicion:
# 382 419 419
# Poscicion:
# 11 329 329
# Poscicion:
# 617 388 388
# Poscicion:
# 285 778 778
# Speed: 3.0ms preprocess, 166.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 5 cars, 1 truck, 145.0ms
# Poscicion:
# 11 329 329
# Poscicion:
# 617 387 387
# Speed: 3.0ms preprocess, 145.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 cars, 1 truck, 170.0ms
# Poscicion:
# 11 329 329
# Poscicion:
# 616 386 386
# Speed: 2.0ms preprocess, 170.0ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 cars, 1 truck, 149.0ms
# Poscicion:
# 11 330 330
# Poscicion:
# 616 384 384
# Speed: 3.0ms preprocess, 149.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 5 cars, 1 truck, 142.2ms
# Poscicion:
# 373 430 430
# Poscicion:
# 11 330 330
# Poscicion:
# 614 382 382
# Speed: 2.0ms preprocess, 142.2ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 cars, 1 truck, 160.0ms
# Poscicion:
# 371 433 433
# Poscicion:
# 11 330 330
# Poscicion:
# 613 381 381
# Speed: 3.0ms preprocess, 160.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 6 cars, 1 truck, 148.0ms
# Poscicion:
# 368 437 437
# Poscicion:
# 11 330 330
# Poscicion:
# 613 379 379
# Speed: 2.0ms preprocess, 148.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 5 cars, 1 truck, 152.0ms
# Poscicion:
# 366 439 439
# Poscicion:
# 11 330 330
# Poscicion:
# 612 378 378
# Speed: 2.0ms preprocess, 152.0ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 5 cars, 1 truck, 162.0ms
# Poscicion:
# 363 443 443
# Poscicion:
# 11 330 330
# Poscicion:
# 610 377 377
# Speed: 3.0ms preprocess, 162.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 5 cars, 1 truck, 150.0ms
# Poscicion:
# 445 432 432
# Poscicion:
# 360 446 446
# Poscicion:
# 11 330 330
# Poscicion:
# 610 376 376
# Speed: 2.0ms preprocess, 150.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 5 cars, 1 truck, 155.2ms
# Poscicion:
# 435 398 398
# Poscicion:
# 445 436 436
# Poscicion:
# 357 450 450
# Poscicion:
# 12 330 330
# Poscicion:
# 609 375 375
# Speed: 3.0ms preprocess, 155.2ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 5 cars, 1 truck, 143.0ms
# Poscicion:
# 354 454 454
# Poscicion:
# 12 330 330
# Poscicion:
# 608 374 374
# Speed: 3.0ms preprocess, 143.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 5 cars, 1 truck, 153.0ms
# Poscicion:
# 351 458 458
# Poscicion:
# 12 330 330
# Poscicion:
# 607 372 372
# Speed: 2.0ms preprocess, 153.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 5 cars, 1 truck, 171.0ms
# Poscicion:
# 347 462 462
# Poscicion:
# 12 330 330
# Poscicion:
# 606 371 371
# Speed: 2.0ms preprocess, 171.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 5 cars, 1 truck, 146.5ms
# Poscicion:
# 438 452 452
# Poscicion:
# 345 465 465
# Poscicion:
# 12 330 330
# Poscicion:
# 606 370 370
# Speed: 3.0ms preprocess, 146.5ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 cars, 1 truck, 162.0ms
# Poscicion:
# 341 470 470
# Poscicion:
# 12 330 330
# Poscicion:
# 605 369 369
# Speed: 2.0ms preprocess, 162.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 5 cars, 1 truck, 149.0ms
# Poscicion:
# 337 474 474
# Poscicion:
# 12 330 330
# Poscicion:
# 605 368 368
# Speed: 2.0ms preprocess, 149.0ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 5 cars, 1 truck, 155.1ms
# Poscicion:
# 334 480 480
# Poscicion:
# 12 330 330
# Poscicion:
# 604 367 367
# Speed: 2.0ms preprocess, 155.1ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 5 cars, 1 truck, 153.0ms
# Poscicion:
# 329 484 484
# Poscicion:
# 11 330 330
# Poscicion:
# 604 365 365
# Speed: 3.0ms preprocess, 153.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 5 cars, 1 truck, 151.0ms
# Poscicion:
# 326 489 489
# Poscicion:
# 11 330 330
# Poscicion:
# 603 364 364
# Speed: 2.0ms preprocess, 151.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 5 cars, 1 truck, 177.5ms
# Poscicion:
# 423 480 480
# Poscicion:
# 425 419 419
# Poscicion:
# 321 495 495
# Poscicion:
# 11 329 329
# Poscicion:
# 603 363 363
# Speed: 2.0ms preprocess, 177.5ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 5 cars, 1 truck, 150.0ms
# Poscicion:
# 421 484 484
# Poscicion:
# 423 423 423
# Poscicion:
# 316 501 501
# Poscicion:
# 11 329 329
# Poscicion:
# 602 362 362
# Speed: 2.0ms preprocess, 150.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 5 cars, 1 truck, 161.5ms
# Poscicion:
# 419 487 487
# Poscicion:
# 421 427 427
# Poscicion:
# 311 508 508
# Poscicion:
# 11 329 329
# Poscicion:
# 601 361 361
# Speed: 2.0ms preprocess, 161.5ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 cars, 157.0ms
# Poscicion:
# 306 515 515
# Poscicion:
# 11 330 330
# Poscicion:
# 601 360 360
# Speed: 2.0ms preprocess, 157.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 cars, 139.0ms
# Poscicion:
# 11 330 330
# Poscicion:
# 600 359 359
# Speed: 2.0ms preprocess, 139.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 5 cars, 153.0ms
# Poscicion:
# 11 329 329
# Poscicion:
# 599 358 358
# Speed: 2.0ms preprocess, 153.0ms inference, 1.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 cars, 1 train, 152.0ms
# Poscicion:
# 11 329 329
# Poscicion:
# 598 358 358
# Speed: 3.0ms preprocess, 152.0ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 5 cars, 152.0ms
# Poscicion:
# 283 542 542
# Poscicion:
# 11 329 329
# Poscicion:
# 598 357 357
# Speed: 2.0ms preprocess, 152.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 5 cars, 159.0ms
# Poscicion:
# 277 552 552
# Poscicion:
# 11 329 329
# Poscicion:
# 597 357 357
# Speed: 2.0ms preprocess, 159.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 5 cars, 146.2ms
# Poscicion:
# 397 548 548
# Poscicion:
# 270 561 561
# Poscicion:
# 11 329 329
# Poscicion:
# 598 356 356
# Speed: 2.0ms preprocess, 146.2ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 5 cars, 144.0ms
# Poscicion:
# 409 462 462
# Poscicion:
# 392 560 560
# Poscicion:
# 262 570 570
# Poscicion:
# 11 330 330
# Poscicion:
# 597 355 355
# Speed: 2.0ms preprocess, 144.0ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 5 cars, 143.0ms
# Poscicion:
# 407 467 467
# Poscicion:
# 388 573 573
# Poscicion:
# 254 581 581
# Poscicion:
# 11 330 330
# Poscicion:
# 596 354 354
# Speed: 2.0ms preprocess, 143.0ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 5 cars, 147.0ms
# Poscicion:
# 404 472 472
# Poscicion:
# 384 585 585
# Poscicion:
# 246 592 592
# Poscicion:
# 11 329 329
# Poscicion:
# 597 353 353
# Speed: 3.0ms preprocess, 147.0ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 5 cars, 147.1ms
# Poscicion:
# 402 477 477
# Poscicion:
# 379 600 600
# Poscicion:
# 237 604 604
# Poscicion:
# 11 329 329
# Poscicion:
# 596 352 352
# Speed: 2.0ms preprocess, 147.1ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 5 cars, 147.0ms
# Poscicion:
# 399 482 482
# Poscicion:
# 373 611 611
# Poscicion:
# 228 618 618
# Poscicion:
# 11 329 329
# Poscicion:
# 596 351 351
# Speed: 2.0ms preprocess, 147.0ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 5 cars, 150.0ms
# Poscicion:
# 397 487 487
# Poscicion:
# 367 624 624
# Poscicion:
# 218 632 632
# Poscicion:
# 11 329 329
# Poscicion:
# 596 350 350
# Speed: 2.0ms preprocess, 150.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 5 cars, 140.0ms
# Poscicion:
# 360 644 644
# Poscicion:
# 207 647 647
# Poscicion:
# 11 329 329
# Poscicion:
# 595 350 350
# Speed: 2.0ms preprocess, 140.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 5 cars, 1 truck, 146.0ms
# Poscicion:
# 353 666 666
# Poscicion:
# 195 661 661
# Poscicion:
# 11 329 329
# Poscicion:
# 595 349 349
# Speed: 3.0ms preprocess, 146.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 5 cars, 155.0ms
# Poscicion:
# 345 686 686
# Poscicion:
# 182 677 677
# Poscicion:
# 12 329 329
# Poscicion:
# 594 348 348
# Speed: 2.0ms preprocess, 155.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 5 cars, 1 truck, 163.5ms
# Poscicion:
# 388 513 513
# Poscicion:
# 337 707 707
# Poscicion:
# 169 697 697
# Poscicion:
# 12 329 329
# Poscicion:
# 594 348 348
# Speed: 2.0ms preprocess, 163.5ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 5 cars, 173.0ms
# Poscicion:
# 385 520 520
# Poscicion:
# 327 736 736
# Poscicion:
# 154 717 717
# Poscicion:
# 12 329 329
# Poscicion:
# 594 347 347
# Speed: 2.0ms preprocess, 173.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 5 cars, 198.2ms
# Poscicion:
# 381 528 528
# Poscicion:
# 316 759 759
# Poscicion:
# 138 741 741
# Poscicion:
# 12 329 329
# Poscicion:
# 593 346 346
# Speed: 2.0ms preprocess, 198.2ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 5 cars, 1 train, 156.0ms
# Poscicion:
# 379 535 535
# Poscicion:
# 305 772 772
# Poscicion:
# 120 760 760
# Poscicion:
# 12 329 329
# Poscicion:
# 592 345 345
# Speed: 2.0ms preprocess, 156.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 5 cars, 163.0ms
# Poscicion:
# 375 545 545
# Poscicion:
# 295 779 779
# Poscicion:
# 100 769 769
# Poscicion:
# 12 329 329
# Poscicion:
# 592 344 344
# Speed: 2.0ms preprocess, 163.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 cars, 154.0ms
# Poscicion:
# 371 553 553
# Poscicion:
# 286 784 784
# Poscicion:
# 12 329 329
# Poscicion:
# 591 344 344
# Speed: 2.0ms preprocess, 154.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 cars, 1 train, 1 truck, 154.5ms
# Poscicion:
# 366 560 560
# Poscicion:
# 12 329 329
# Poscicion:
# 591 343 343
# Speed: 2.0ms preprocess, 154.5ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 3 cars, 1 truck, 156.2ms
# Poscicion:
# 363 573 573
# Poscicion:
# 12 329 329
# Poscicion:
# 591 343 343
# Speed: 2.0ms preprocess, 156.2ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 3 cars, 1 truck, 156.0ms
# Poscicion:
# 359 584 584
# Poscicion:
# 12 329 329
# Poscicion:
# 591 342 342
# Speed: 2.0ms preprocess, 156.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
